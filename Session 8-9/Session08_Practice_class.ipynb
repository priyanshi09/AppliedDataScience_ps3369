# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
# %pylab inline
from sklearn.model_selection import train_test_split
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Crime Rate in 47 states of the USA with 13 explanatory variables
# The crime rate (**Y**) in 47 states in the U.S. was reported together with possible factors that might influence it. The factors recorded are as follows;
# X1 = the number of males aged 14 - 24 per 1000 of total state population
# X2 = binary variable distinguishing southern states (X2 =1) from the rest (X2=0).
# X3 = the mean number of years of schooling x 10 of the population, 25 years old and over
# X4 = police expenditure (in dollars) per person by state and local government in 1960
# X5 = police expenditure (in dollars) per person by state and local government in 1959
# X6 = labour force participation rate per 1000 civilian urban males in the age group 14-24
# X7 = the number of males per 1000 females
# X8 = state population size in hundred thousands
# X9 = unemployment rate of urban males per 1000 in the age group 14-24
# X10 = unemployment rate of urban males per 1000 in the age group 35-59.
# X11 = the median value of family income or transferable goods and assets (unit 10 dollars)
# X12 = the number of families per 1000 earning below one-half of the median income.

# %%
data = pd.read_excel('https://serv.cusp.nyu.edu/~cq299/ADS2016/Data/Crime.xlsx')

# %%
feature = ['males','south','yrsSch','policExp60','policeExp59','labour',
           'M/F','statePop','unemp14','unemp35','income','proverty']

# %%
print(data.shape)
data.head()
data.columns
# Out:
# (47, 13)
# Index(['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11',
#        'X12', 'Y'],
#       dtype='object')

# %%
# Q1. Looking at the impact of each feature separately (on all 47 observations)
    # Fitting bi-variate regressions and reporting the statistics
# Q2. Take for the further consideration only those which have p-value < 5% (in their bi-variate regressions)
    # Compute correlation matrix among those
# Q3. Fit the multi-variate regression with X3, X4, X8, X11, report statistics, visualize prediction vs reality
# Q4. Run cross-validation with the regressors in Q3, report the Out-of-sample R2 (OS R2)
    # Put 30 observations into training set and the remaining 17 into test set
    # Run it 100 times, obtain the average value
# Q5. Run cross-validation with X4 only, same settings as Q4, then compare your OS R2 with the counterpart in Q4

# %%
lm1 = smf.ols(formula='Y ~ X1', data = data).fit()
lm2 = smf.ols(formula='Y ~ X2', data = data).fit()
lm3 = smf.ols(formula='Y ~ X3', data = data).fit()
lm4 = smf.ols(formula='Y ~ X4', data = data).fit()
lm5 = smf.ols(formula='Y ~ X5', data = data).fit()
lm6 = smf.ols(formula='Y ~ X6', data = data).fit()
lm7 = smf.ols(formula='Y ~ X7', data = data).fit()
lm8 = smf.ols(formula='Y ~ X8', data = data).fit()
lm9 = smf.ols(formula='Y ~ X9', data = data).fit()
lm10 = smf.ols(formula='Y ~ X10', data = data).fit()
lm11 = smf.ols(formula='Y ~ X11', data = data).fit()
lm12 = smf.ols(formula='Y ~ X12', data = data).fit()

# %%
lm1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                    0.3631
# Date:                Fri, 04 Nov 2016   Prob (F-statistic):              0.550
# Time:                        18:50:34   Log-Likelihood:                -237.79
# No. Observations:                  47   AIC:                             479.6
# Df Residuals:                      45   BIC:                             483.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    128.6646     63.572      2.024      0.049         0.625   256.705
# X1            -0.2753      0.457     -0.603      0.550        -1.196     0.645
# ==============================================================================
# Omnibus:                       10.177   Durbin-Watson:                   2.466
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):                9.628
# Skew:                           1.030   Prob(JB):                      0.00812
# Kurtosis:                       3.822   Cond. No.                     1.56e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.56e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                    0.3727
# Date:                Fri, 04 Nov 2016   Prob (F-statistic):              0.545
# Time:                        18:50:56   Log-Likelihood:                -237.79
# No. Observations:                  47   AIC:                             479.6
# Df Residuals:                      45   BIC:                             483.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     93.0000      6.994     13.297      0.000        78.913   107.087
# X2            -7.3187     11.988     -0.611      0.545       -31.463    16.826
# ==============================================================================
# Omnibus:                        9.658   Durbin-Watson:                   2.445
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):                8.989
# Skew:                           0.999   Prob(JB):                       0.0112
# Kurtosis:                       3.774   Cond. No.                         2.41
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.104
# Model:                            OLS   Adj. R-squared:                  0.084
# Method:                 Least Squares   F-statistic:                     5.236
# Date:                Fri, 04 Nov 2016   Prob (F-statistic):             0.0269
# Time:                        18:51:03   Log-Likelihood:                -235.39
# No. Observations:                  47   AIC:                             474.8
# Df Residuals:                      45   BIC:                             478.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    -27.3967     51.810     -0.529      0.600      -131.748    76.955
# X3             1.1161      0.488      2.288      0.027         0.134     2.099
# ==============================================================================
# Omnibus:                        5.472   Durbin-Watson:                   2.456
# Prob(Omnibus):                  0.065   Jarque-Bera (JB):                4.820
# Skew:                           0.782   Prob(JB):                       0.0898
# Kurtosis:                       3.118   Cond. No.                     1.02e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.02e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
lm4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.473
# Model:                            OLS   Adj. R-squared:                  0.461
# Method:                 Least Squares   F-statistic:                     40.36
# Date:                Fri, 04 Nov 2016   Prob (F-statistic):           9.34e-08
# Time:                        18:51:15   Log-Likelihood:                -222.94
# No. Observations:                  47   AIC:                             449.9
# Df Residuals:                      45   BIC:                             453.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     14.4464     12.669      1.140      0.260       -11.071    39.964
# X4             0.8948      0.141      6.353      0.000         0.611     1.179
# ==============================================================================
# Omnibus:                        0.527   Durbin-Watson:                   2.122
# Prob(Omnibus):                  0.768   Jarque-Bera (JB):                0.568
# Skew:                          -0.233   Prob(JB):                        0.753
# Kurtosis:                       2.729   Cond. No.                         275.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.445
# Model:                            OLS   Adj. R-squared:                  0.432
# Method:                 Least Squares   F-statistic:                     36.01
# Date:                Fri, 04 Nov 2016   Prob (F-statistic):           3.11e-07
# Time:                        18:51:20   Log-Likelihood:                -224.16
# No. Observations:                  47   AIC:                             452.3
# Df Residuals:                      45   BIC:                             456.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     16.5164     13.043      1.266      0.212        -9.753    42.786
# X5             0.9222      0.154      6.001      0.000         0.613     1.232
# ==============================================================================
# Omnibus:                        0.293   Durbin-Watson:                   2.172
# Prob(Omnibus):                  0.864   Jarque-Bera (JB):                0.359
# Skew:                          -0.173   Prob(JB):                        0.836
# Kurtosis:                       2.749   Cond. No.                         260.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.036
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     1.665
# Date:                Fri, 04 Nov 2016   Prob (F-statistic):              0.204
# Time:                        18:51:26   Log-Likelihood:                -237.13
# No. Observations:                  47   AIC:                             478.3
# Df Residuals:                      45   BIC:                             482.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    -10.9298     78.823     -0.139      0.890      -169.687   147.828
# X6             0.1808      0.140      1.290      0.204        -0.101     0.463
# ==============================================================================
# Omnibus:                        7.779   Durbin-Watson:                   2.427
# Prob(Omnibus):                  0.020   Jarque-Bera (JB):                6.966
# Skew:                           0.914   Prob(JB):                       0.0307
# Kurtosis:                       3.465   Cond. No.                     7.92e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.92e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
lm7.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.046
# Model:                            OLS   Adj. R-squared:                  0.025
# Method:                 Least Squares   F-statistic:                     2.158
# Date:                Fri, 04 Nov 2016   Prob (F-statistic):              0.149
# Time:                        18:51:31   Log-Likelihood:                -236.88
# No. Observations:                  47   AIC:                             477.8
# Df Residuals:                      45   BIC:                             481.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   -185.4895    187.966     -0.987      0.329      -564.073   193.094
# X7             0.2808      0.191      1.469      0.149        -0.104     0.666
# ==============================================================================
# Omnibus:                        6.522   Durbin-Watson:                   2.299
# Prob(Omnibus):                  0.038   Jarque-Bera (JB):                5.594
# Skew:                           0.822   Prob(JB):                       0.0610
# Kurtosis:                       3.395   Cond. No.                     3.32e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.32e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
lm8.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.114
# Model:                            OLS   Adj. R-squared:                  0.094
# Method:                 Least Squares   F-statistic:                     5.784
# Date:                Fri, 04 Nov 2016   Prob (F-statistic):             0.0204
# Time:                        18:51:46   Log-Likelihood:                -235.14
# No. Observations:                  47   AIC:                             474.3
# Df Residuals:                      45   BIC:                             478.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     77.9548      7.488     10.410      0.000        62.872    93.037
# X8             0.3428      0.143      2.405      0.020         0.056     0.630
# ==============================================================================
# Omnibus:                       12.401   Durbin-Watson:                   2.504
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               12.621
# Skew:                           1.111   Prob(JB):                      0.00182
# Kurtosis:                       4.229   Cond. No.                         73.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm9.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.020
# Method:                 Least Squares   F-statistic:                    0.1150
# Date:                Fri, 04 Nov 2016   Prob (F-statistic):              0.736
# Time:                        18:51:56   Log-Likelihood:                -237.92
# No. Observations:                  47   AIC:                             479.8
# Df Residuals:                      45   BIC:                             483.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    100.8465     31.019      3.251      0.002        38.371   163.322
# X9            -0.1083      0.319     -0.339      0.736        -0.752     0.535
# ==============================================================================
# Omnibus:                       11.490   Durbin-Watson:                   2.488
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               11.315
# Skew:                           1.099   Prob(JB):                      0.00349
# Kurtosis:                       3.972   Cond. No.                         529.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm10.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     1.461
# Date:                Fri, 04 Nov 2016   Prob (F-statistic):              0.233
# Time:                        18:52:03   Log-Likelihood:                -237.23
# No. Observations:                  47   AIC:                             478.5
# Df Residuals:                      45   BIC:                             482.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     62.9162     23.509      2.676      0.010        15.567   110.266
# X10            0.8120      0.672      1.209      0.233        -0.541     2.165
# ==============================================================================
# Omnibus:                        9.539   Durbin-Watson:                   2.328
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):                8.859
# Skew:                           0.997   Prob(JB):                       0.0119
# Kurtosis:                       3.741   Cond. No.                         147.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm11.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.195
# Model:                            OLS   Adj. R-squared:                  0.177
# Method:                 Least Squares   F-statistic:                     10.88
# Date:                Fri, 04 Nov 2016   Prob (F-statistic):            0.00190
# Time:                        18:52:09   Log-Likelihood:                -232.89
# No. Observations:                  47   AIC:                             469.8
# Df Residuals:                      45   BIC:                             473.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -2.4283     28.631     -0.085      0.933       -60.095    55.238
# X11            0.1769      0.054      3.299      0.002         0.069     0.285
# ==============================================================================
# Omnibus:                        3.746   Durbin-Watson:                   2.193
# Prob(Omnibus):                  0.154   Jarque-Bera (JB):                3.203
# Skew:                           0.639   Prob(JB):                        0.202
# Kurtosis:                       2.989   Cond. No.                     2.99e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.99e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
lm12.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.032
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     1.490
# Date:                Fri, 04 Nov 2016   Prob (F-statistic):              0.229
# Time:                        18:52:14   Log-Likelihood:                -237.21
# No. Observations:                  47   AIC:                             478.4
# Df Residuals:                      45   BIC:                             482.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    124.1773     28.148      4.412      0.000        67.485   180.870
# X12           -0.1736      0.142     -1.221      0.229        -0.460     0.113
# ==============================================================================
# Omnibus:                        8.646   Durbin-Watson:                   2.461
# Prob(Omnibus):                  0.013   Jarque-Bera (JB):                7.831
# Skew:                           0.948   Prob(JB):                       0.0199
# Kurtosis:                       3.636   Cond. No.                         993.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
data.head()
X= data.iloc[:,:-1]
print(X.head())
lm_actual= smf.ols(formula='Y ~ X', data = data).fit()
lm_actual.summary()
# Out:
#     X1  X2   X3   X4   X5   X6    X7   X8   X9  X10  X11  X12
# 0  151   1   91   58   56  510   950   33  108   41  394  261
# 1  143   0  113  103   95  583  1012   13   96   36  557  194
# 2  142   1   89   45   44  533   969   18   94   33  318  250
# 3  136   0  121  149  141  577   994  157  102   39  673  167
# 4  141   0  121  109  101  591   985   18   91   20  578  174
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.769
# Model:                            OLS   Adj. R-squared:                  0.688
# Method:                 Least Squares   F-statistic:                     9.440
# Date:                Fri, 04 Nov 2016   Prob (F-statistic):           1.16e-07
# Time:                        19:10:56   Log-Likelihood:                -203.53
# No. Observations:                  47   AIC:                             433.1
# Df Residuals:                      34   BIC:                             457.1
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   -690.2970    153.012     -4.511      0.000     -1001.255  -379.339
# X[0]           1.0555      0.393      2.684      0.011         0.256     1.855
# X[1]          -7.5083     12.909     -0.582      0.565       -33.743    18.727
# X[2]           1.7893      0.631      2.836      0.008         0.507     3.072
# X[3]           1.5964      1.038      1.537      0.133        -0.514     3.707
# X[4]          -0.6418      1.110     -0.578      0.567        -2.897     1.614
# X[5]          -0.0354      0.143     -0.248      0.806        -0.326     0.255
# X[6]           0.1589      0.200      0.793      0.433        -0.248     0.566
# X[7]          -0.0412      0.128     -0.323      0.749        -0.301     0.218
# X[8]          -0.5932      0.424     -1.398      0.171        -1.456     0.269
# X[9]           1.7915      0.844      2.124      0.041         0.077     3.506
# X[10]          0.1347      0.102      1.325      0.194        -0.072     0.341
# X[11]          0.7942      0.231      3.432      0.002         0.324     1.264
# ==============================================================================
# Omnibus:                        0.367   Durbin-Watson:                   1.469
# Prob(Omnibus):                  0.832   Jarque-Bera (JB):                0.250
# Skew:                           0.173   Prob(JB):                        0.883
# Kurtosis:                       2.908   Cond. No.                     6.24e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.24e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
data1= data[['X3','X4','X8','X11']]

# %%
data1.head()
# Out:
#     X3   X4   X8  X11
# 0   91   58   33  394
# 1  113  103   13  557
# 2   89   45   18  318
# 3  121  149  157  673
# 4  121  109   18  578

# %%
data1.corr()
# Out:
#            X3        X4        X8       X11
# X3   1.000000  0.482952 -0.017227  0.735997
# X4   0.482952  1.000000  0.526284  0.787225
# X8  -0.017227  0.526284  1.000000  0.308263
# X11  0.735997  0.787225  0.308263  1.000000

# %%
lm_final = smf.ols(formula='Y ~ X3+ X4+X8 +X11', data = data).fit()
lm_final.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.516
# Model:                            OLS   Adj. R-squared:                  0.470
# Method:                 Least Squares   F-statistic:                     11.20
# Date:                Fri, 04 Nov 2016   Prob (F-statistic):           2.85e-06
# Time:                        19:29:32   Log-Likelihood:                -220.93
# No. Observations:                  47   AIC:                             451.9
# Df Residuals:                      42   BIC:                             461.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     11.5368     42.386      0.272      0.787       -74.001    97.074
# X3             0.6305      0.593      1.062      0.294        -0.567     1.828
# X4             1.2536      0.259      4.836      0.000         0.730     1.777
# X8            -0.0306      0.138     -0.222      0.826        -0.309     0.248
# X11           -0.1771      0.093     -1.907      0.063        -0.365     0.010
# ==============================================================================
# Omnibus:                        0.750   Durbin-Watson:                   2.311
# Prob(Omnibus):                  0.687   Jarque-Bera (JB):                0.485
# Skew:                          -0.249   Prob(JB):                        0.785
# Kurtosis:                       2.976   Cond. No.                     5.70e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.7e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
y_fit = lm_final.predict(data)   # Calculate the predicted value
plt.figure(figsize = (8,6))
plt.plot(y_fit,data.Y,'or', markersize = 8) # Plot the observed value, linestyle = 'or', red dots
plt.plot(y_fit,y_fit,'--b', linewidth = 1)                 # Plot the predicted value, blue dashed line

# Plot setting
plt.xlabel('Prediction', fontsize = 16)
plt.ylabel('Observation', fontsize = 16)

# %%
# Q4. Run cross-validation with the regressors in Q3, report the Out-of-sample R2 (OS R2)
    # Put 30 observations into training set and the remaining 17 into test set
    # Run it 100 times, obtain the average value
data.head()
# Out:
#     X1  X2   X3   X4   X5   X6    X7   X8   X9  X10  X11  X12      Y
# 0  151   1   91   58   56  510   950   33  108   41  394  261   79.1
# 1  143   0  113  103   95  583  1012   13   96   36  557  194  163.5
# 2  142   1   89   45   44  533   969   18   94   33  318  250   57.8
# 3  136   0  121  149  141  577   994  157  102   39  673  167  196.9
# 4  141   0  121  109  101  591   985   18   91   20  578  174  123.4

# %%
x=data.iloc[:30,0:-1]
y=np.asarray(data.Y.iloc[:30])
y.shape
# Out:
# (30,)

# %%
from sklearn.linear_model import LinearRegression
x=data.iloc[:46,0:-1]
y=np.asarray(data.Y.iloc[:46])
R_IS=[]
R_OS=[]
n=100
for i in range(n):
    X_train, X_test = train_test_split(data, test_size= 17.0/47)
    X_train, X_test, y_train, y_test = train_test_split(np.asarray(x.iloc[:,[2,3,7,10]]), y, test_size=0.33)
    res=LinearRegression(fit_intercept=False)
    res.fit(X_train,y_train)
    R_IS.append(1-((np.asarray(res.predict(X_train))-y_train)**2).sum()/((y_train-np.mean(y_train))**2).sum())                                                                     
    R_OS.append(1-((np.asarray(res.predict(X_test))-y_test)**2).sum()/((y_test-np.mean(y_test))**2).sum())
print("IS R-squared for {} times is {}".format(n,np.mean(R_IS)))
print("OS R-squared for {} times is {}".format(n,np.mean(R_OS)))
# Out:
# IS R-squared for 100 times is 0.5354729187885723
# OS R-squared for 100 times is 0.11580646008577576

# %%
#  Q5. Run cross-validation with X4 only, same settings as Q4, then compare your OS R2 with the counterpart in Q4
from sklearn.linear_model import LinearRegression
x=data.iloc[:30,0:-1]
y=np.asarray(data.Y.iloc[:30])
R_IS=[]
R_OS=[]
n=100
for i in range(n):
    X_train, X_test, y_train, y_test = train_test_split(np.asarray(x.iloc[:,[2,7,10]]), y, test_size=0.33)
    res=LinearRegression(fit_intercept=False)
    res.fit(X_train,y_train)
    R_IS.append(1-((np.asarray(res.predict(X_train))-y_train)**2).sum()/((y_train-np.mean(y_train))**2).sum())                                                                     
    R_OS.append(1-((np.asarray(res.predict(X_test))-y_test)**2).sum()/((y_test-np.mean(y_test))**2).sum())
print("IS R-squared for {} times is {}".format(n,np.mean(R_IS)))
print("OS R-squared for {} times is {}".format(n,np.mean(R_OS)))
# Out:
# IS R-squared for 100 times is 0.3542575273948368
# OS R-squared for 100 times is -0.2696011358879932
